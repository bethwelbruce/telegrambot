# %%
# !pip install telethon
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.2/702.2 kB 36.7 MB/s eta 0:00:00
# ...
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26346 sha256=7023fbbe4540d0659ab990cc62e9d4dfa5b4c07ec7392a0d3cb40452ae7f76b2
#   Stored in directory: /root/.cache/pip/wheels/d6/84/5f/ea6aef85a93c7e1922486369874f4740a5642d261e09c59140
# Successfully built pyaes
# ...

# %%
# -*- coding: utf-8 -*-
"""forwarder script.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/15u5ItCdT9Fgi6uzBEZXhCfbd6LwOJNKl
"""

# !pip install telethon

from telethon import TelegramClient, events

# Your API credentials
api_id = 23231040
api_hash = '9d4b9340a64b23e153bd0f25817d9c57'

# Initialize the Telegram client
client = TelegramClient('user_session', api_id, api_hash)

async def main():
    await client.start()

    # Source and destination chat details
    source_chat = "QuartzETH"  # Replace with the source public group's username
    destination_chat = "Jessieewow"  # Replace with the destination public group's username

    @client.on(events.NewMessage(chats=source_chat))
    async def forward_message(event):
        try:
            # Access the original message
            original_message = event.message.message

            # Modify the message text
            if "Called first @quartzvip" in original_message:
                modified_message = original_message.replace("Called first @quartzvip", "Called first @Jessievip")

                # Send the modified message to the destination chat
                await client.send_message(destination_chat, modified_message)
                print(f"Modified message successfully forwarded: {modified_message}")
            else:
                # Forward the unmodified message
                await client.forward_messages(destination_chat, event.message)
                print(f"Message successfully forwarded: {original_message}")
        except Exception as e:
            print(f"Error while forwarding message: {e}")

    print("Bot is running. Press Ctrl+C to stop.")
    await client.run_until_disconnected()

await main()
# Out:
# +86 176 5991 2635Requirement already satisfied: telethon in /usr/local/lib/python3.10/dist-packages (1.38.1)
# ...
# Signed in successfully as kim AB; remember to not break the ToS or you will risk an account ban!
# Bot is running. Press Ctrl+C to stop.
# Modified message successfully forwarded: 2x plus from call 🔥 now 276k
#
# Called first @Jessievip
#
# https://dexscreener.com/ethereum/0xb5fa7edfd5e3c27480763a066c2fa6b12fce24e8
#
# $LTC 🚀🚀
